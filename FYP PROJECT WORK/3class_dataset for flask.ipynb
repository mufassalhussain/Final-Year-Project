# %%
#%cp -av /content/drive/MyDrive/data_upload_v3/test/non/Atelectasis /content/drive/MyDrive/otherdisease

# %%
import cv2,os
data_path='/content/drive/MyDrive/Finaldata/train'
categories=os.listdir(data_path)
labels=[i for i in range(len(categories))]

label_dict=dict(zip(categories,labels))

# %%
print(label_dict)
# Out:
# {'Covid19 Negative': 0, 'Covid19 Positive': 1, 'Other Disease': 2}

# %%
print(categories)
# Out:
# ['Covid19 Negative', 'Covid19 Positive', 'Other Disease']

# %%
img_size=100
data=[]
target=[]
for category in categories:
    folder_path=os.path.join(data_path,category)
    img_names=os.listdir(folder_path)
    
    for img_name in img_names:
        img_path=os.path.join(folder_path,img_name)
        img=cv2.imread(img_path)
        
        try:
            gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
            #converting pic to grayscale
            resized=cv2.resize(gray,(img_size,img_size))
            #resizing image into 100x100 since we need fixed common size for all image
            data.append(resized)
            target.append(label_dict[category])
            #appending the image and the label(categorized) into the list dataset
            
        except Exception as e:
            print('Exception :',e)
            #if any exception raised,the exception will be printed here,and pass to next image
# Out:
# Exception : OpenCV(4.1.2) /io/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %%
import keras
import tensorflow
import numpy as np
data=np.array(data)/255.0
data=np.reshape(data,(data.shape[0],img_size,img_size,1))
target=np.array(target)

from keras.utils import np_utils

new_target=np_utils.to_categorical(target)

# %%
np.save('data',data)
np.save('target',new_target)
